# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    https://www.kaggle.com/datasets/atharvaingle/crop-recommendation-dataset/data

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from scikit-learn) (3.6.0)

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (2.22.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: Flask<4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (3.1.1)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (1.16.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: numpy<3 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (2.2.6)
# Requirement already satisfied: pandas<3 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (2.0.41)
# Requirement already satisfied: waitress<4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.53.0)
# Requirement already satisfied: fastapi<1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (1.33.1)
# Requirement already satisfied: packaging<25 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (6.31.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (2.11.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Requirement already satisfied: uvicorn<1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (0.34.2)
# Requirement already satisfied: Mako in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: colorama in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.22.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (2.40.2)
# Requirement already satisfied: pywin32>=304 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.4.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow) (0.46.2)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib<4->mlflow) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.54b1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from scikit-learn<2->mlflow) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\krisn\agriculture_submission_membangun_machine_learning\.venv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.2)

# %%
#Type your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mlflow
import mlflow.sklearn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
#Type your code here
# Load dataset dari URL
url = "https://raw.githubusercontent.com/Ezraliano/Agriculture_Submission_Membangun_Sistem_Machine_Learning/refs/heads/main/Eksperimen_SML_Ezraliano/dataset_raw/Crop_recommendation.csv "
df = pd.read_csv(url)

# Tampilkan beberapa baris pertama
print(df.head())
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %%
#Type your code here
# Informasi dataset
print(df.info())

# Statistik deskriptif
print(df.describe())

# Cek jumlah kelas pada target 'label'
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='label', order=df['label'].value_counts().index)
plt.title("Distribusi Jenis Tanaman")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB
# None
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
# Korelasi antar fitur
plt.figure(figsize=(10, 8))
# Drop the non-numeric 'label' column before calculating correlation
corr = df.drop('label', axis=1).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Matriks Korelasi Fitur")
plt.show()

# %%
# Pengecekan Outliers menggunakan IQR
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return len(outliers), lower_bound, upper_bound

print("\nPengecekan Outliers:")
for column in df.select_dtypes(include=[np.number]).columns:
    count, lower, upper = detect_outliers(df, column)
    print(f"Kolom {column}: {count} outliers (Batas bawah: {lower:.2f}, Batas atas: {upper:.2f})")
# Out:
# Pengecekan Outliers:
# Kolom N: 0 outliers (Batas bawah: -73.88, Batas atas: 179.12)
# Kolom P: 138 outliers (Batas bawah: -32.00, Batas atas: 128.00)
# Kolom K: 200 outliers (Batas bawah: -23.50, Batas atas: 92.50)
# Kolom temperature: 86 outliers (Batas bawah: 14.08, Batas atas: 37.25)
# Kolom humidity: 30 outliers (Batas bawah: 15.73, Batas atas: 134.48)
# Kolom ph: 57 outliers (Batas bawah: 4.54, Batas atas: 8.35)
# Kolom rainfall: 100 outliers (Batas bawah: -25.02, Batas atas: 213.84)

# %%
# Pengecekan Skewness
print("\nSkewness Fitur Numerik:")
skewness = df.select_dtypes(include=[np.number]).skew()
print(skewness)

# Visualisasi distribusi fitur numerik untuk melihat skewness
for column in df.select_dtypes(include=[np.number]).columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[column], kde=True)
    plt.title(f"Distribusi {column} (Skewness: {df[column].skew():.2f})")
    plt.show()
# Out:
# Skewness Fitur Numerik:
# N              0.509721
# P              1.010773
# K              2.375167
# temperature    0.184933
# humidity      -1.091708
# ph             0.283929
# rainfall       0.965756
# dtype: float64

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
# Memisahkan fitur dan target
X = df.drop('label', axis=1)
y = df['label']

# Standarisasi fitur numerik
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Memeriksa nilai duplikat
print("Jumlah data duplikat sebelum penghapusan:", df.duplicated().sum())
# Out:
# Jumlah data duplikat sebelum penghapusan: 0

# %%
# Memeriksa nilai kosong / missing values
print("\nJumlah nilai kosong per kolom:")
print(df.isnull().sum())
# Out:
# Jumlah nilai kosong per kolom:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# Standarisasi fitur numerik
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 6. Modeling

# %%
# Membuat model Logistic Regression untuk multiclass
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)
model.fit(X_train, y_train)
# Out:
# c:\Users\krisn\Agriculture_Submission_Membangun_Machine_Learning\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %% [markdown]
# ## 7. Evaluation

# %%
# Prediksi pada data test
y_pred = model.predict(X_test)

# Evaluasi model
print("Akurasi:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Akurasi: 0.9727272727272728
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        20
#       banana       1.00      1.00      1.00        20
#    blackgram       0.95      1.00      0.98        20
#     chickpea       1.00      1.00      1.00        20
#      coconut       0.95      1.00      0.98        20
#       coffee       1.00      1.00      1.00        20
#       cotton       0.95      1.00      0.98        20
#       grapes       1.00      1.00      1.00        20
#         jute       0.83      1.00      0.91        20
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.85      0.89        20
#        maize       1.00      0.95      0.97        20
#        mango       0.95      1.00      0.98        20
#    mothbeans       0.90      0.90      0.90        20
#     mungbean       1.00      1.00      1.00        20
#    muskmelon       1.00      1.00      1.00        20
#       orange       1.00      0.95      0.97        20
#       papaya       1.00      0.95      0.97        20
#   pigeonpeas       1.00      1.00      1.00        20
#  pomegranate       1.00      1.00      1.00        20
#         rice       0.94      0.80      0.86        20
#   watermelon       1.00      1.00      1.00        20
#
#     accuracy                           0.97       440
#    macro avg       0.97      0.97      0.97       440
# weighted avg       0.97      0.97      0.97       440

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## 8. Inference

# %%
# Contoh prediksi baru
# Format input: [N, P, K, temperature, humidity, ph, rainfall]

new_data = [[90, 42, 43, 20.87, 82.0, 6.5, 202.93]]  # Contoh data dummy
new_data_scaled = scaler.transform(new_data)

predicted_crop = model.predict(new_data_scaled)
print("Prediksi jenis tanaman:", predicted_crop[0])
# Out:
# Prediksi jenis tanaman: rice
# c:\Users\krisn\Agriculture_Submission_Membangun_Machine_Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Export prediksi ke file CSV
def export_predictions_to_csv(data, predictions, filename="crop_prepocessing.csv"):
    # Membuat DataFrame dari data input dan prediksi
    columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
    df_predictions = pd.DataFrame(data, columns=columns)
    df_predictions['predicted_crop'] = predictions
    # Menyimpan ke CSV
    df_predictions.to_csv(filename, index=False)
    print(f"Prediksi telah diekspor ke {filename}")

# Ekspor prediksi contoh ke CSV
export_predictions_to_csv(new_data, predicted_crop)
# Out:
# Prediksi telah diekspor ke crop_prepocessing.csv
